# %%
import pandas as pd
import numpy as np

# %%
dfor = pd.read_csv('/home/poyraden/Analysis/Homogenization_Analysis/Files/Nilu/Sodankyl/Current/SO030301_rawcurrent.csv')

# %%
print(list(dfor))
# Out:
# ['Unnamed: 0', 'Time', 'Height', 'Tbox', 'SolutionVolume', 'SolutionConcentration', 'PF', 'iB0', 'iB2', 'Pground', 'TLab', 'ULab', 'PumpTable', 'PumpTempLoc', 'SerialECC', 'SensorType', 'Pair', 'O3', 'T', 'U', 'Cef', 'ibg', 'Pcor', 'I', 'Date']

# %%
dfr = pd.read_hdf('/home/poyraden/Analysis/Homogenization_public/Files/sodankyla/Current/so030301_rawcurrent.hdf')

# %%
print(list(dfr))
# Out:
# ['Pair', 'Time', 'Height', 'TboxK', 'TboxC', 'WindDirection', 'WindSpeed', 'O3', 'T', 'U', 'SensorType', 'SolutionVolume', 'Cef', 'ibg', 'CorP', 'Pground', 'Pcor', 'I', 'Date']

# %%
dfor[['Pair','ibg','Pground', 'Pcor']]
# Out:
#         Pair       ibg  Pground  Pcor
# 0     1002.7  0.037989   1003.1     0
# 1     1000.9  0.037940   1003.1     0
# 2     1000.2  0.037922   1003.1     0
# 3      999.5  0.037903   1003.1     0
# 4      998.5  0.037875   1003.1     0
# ...      ...       ...      ...   ...
# 2461    21.5  0.001494   1003.1     0
# 2462    21.5  0.001494   1003.1     0
# 2463    21.4  0.001490   1003.1     0
# 2464    21.4  0.001490   1003.1     0
# 2465    21.4  0.001490   1003.1     0
#
# [2466 rows x 4 columns]

# %%
dfr[['Pair','ibg','Pground', 'Pcor','CorP' ]]
# Out:
#         Pair    ibg  Pground  Pcor      CorP
# 1     1000.9  0.038     1000   1.0  0.098466
# 2     1000.2  0.038     1000   1.0  0.098466
# 3      999.5  0.038     1000   1.0  0.098466
# 4      998.5  0.038     1000   1.0  0.098466
# 5      997.0  0.038     1000   1.0  0.098466
# ...      ...    ...      ...   ...       ...
# 2299    21.8  0.038     1000   1.0  0.098466
# 2300    21.7  0.038     1000   1.0  0.098466
# 2301    21.6  0.038     1000   1.0  0.098466
# 2302    21.5  0.038     1000   1.0  0.098466
# 2303    21.4  0.038     1000   1.0  0.098466
#
# [2303 rows x 5 columns]

# %%
dfm = pd.read_csv('/home/poyraden/Analysis/Homogenization_public/Files/sodankyla/Metadata/so030301_metadata.csv')

# %%
print(list(dfm))
# Out:
# ['Unnamed: 0', 'BkgUsed', 'LaunchTime', 'Longitude', 'Latitude', 'SolutionVolume', 'SolutionConcentration', 'PF', 'iB0', 'iB2', 'DurationSurfaceOzoneExposure', 'SurfaceOzone', 'Pground', 'SondeTotalO3', 'TotalO3_Col2A', 'TotalO3_Col2B', 'CorrectionFactor', 'TLab', 'ULab', 'GroundEquipment', 'PumpTable', 'BackgroundCorrection', 'PumpTempLoc', 'SerialECC', 'SensorType', 'InterfaceSerial', 'RadiosondeModel', 'RadiosondeSerial', 'Date']

# %%
dfm[['iB0', 'iB2']]
# Out:
#      iB0    iB2
# 0  0.045  0.038

# %%
dfh = pd.read_hdf('/home/poyraden/Analysis/Homogenization_public/Files/sodankyla/DQA/20150722_all_hom.hdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bb8ea5e8e8a9> in <module>
# ----> 1 dfh = pd.read_hdf('/home/poyraden/Analysis/Homogenization_public/Files/sodankyla/DQA/20150722_all_hom.hdf')
#
# NameError: name 'pd' is not defined

# %%
dfh
# Out:
#        Pair    Time   Height  TboxC  WindDirection  WindSpeed    O3     T  \
# 1     982.0     2.0    188.0   26.8           87.0        1.4  1.99  11.6
# 2     980.9     4.0    197.0   26.8           84.0        1.6  2.00  11.3
# 3     979.8     6.0    207.0   26.8           81.0        1.8  2.00  11.1
# 4     978.7     8.0    217.0   26.8           78.0        2.0  2.00  11.1
# 5     977.4    10.0    228.0   26.8           76.0        2.2  2.02  11.0
# ...     ...     ...      ...    ...            ...        ...   ...   ...
# 2650    5.0  7062.0  37034.0   13.6          109.0        6.8  2.62 -19.7
# 2651    4.9  7090.0  37191.0   13.6          122.0        4.4  2.55 -19.3
# 2652    4.8  7112.0  37343.0   13.5          114.0        6.4  2.48 -19.3
# 2653    4.7  7140.0  37500.0   13.5          105.0       10.7  2.42 -18.8
# 2654    4.6  7160.0  37653.0   13.5          109.0       10.5  2.39 -18.3
#
#          U         I  ...     O3_nc   O3c_eta   O3c_bkg  O3c_phip  O3c_tpump  \
# ...

# %%
dfm  = pd.read_csv('/home/poyraden/Analysis/Homogenization_public/Files/sodankyla/Metadata/so050301_metadata.csv')

# %%
print(list(dfm))
# Out:
# ['Unnamed: 0', 'BkgUsed', 'LaunchTime', 'Longitude', 'Latitude', 'SerialECC', 'SensorType', 'RadiosondeModel', 'RadiosondeSerial', 'PF', 'iB0', 'iB2', 'Date']

# %%
dfm
# Out:
#    Unnamed: 0   BkgUsed  LaunchTime  Longitude  Latitude SerialECC SensorType  \
# 0           0  Constant      18.642      26.65     67.39   6A17434        SPC
#
#   RadiosondeModel  RadiosondeSerial    PF   iB0   iB2      Date
# 0            RS80           2012920  9999  9999  9999  20050301

# %%
dfnd = pd.read_csv('/home/poyraden/Analysis/Homogenization_public/Files/sodankyla/Metadata/All_metadata.csv')

# %%
dfnd = dfnd.sort_values(['Date'])

# %%
dfnd[['Date', 'PF','iB2']]
# Out:
#          Date       PF       iB2
# 916  19911120  9999.00  9999.000
# 917  19911127  9999.00  9999.000
# 918  19911202  9999.00  9999.000
# 919  19911203  9999.00  9999.000
# 920  19911204  9999.00  9999.000
# ..        ...      ...       ...
# 911  20190709    28.58     0.002
# 912  20190725    28.15     0.007
# 913  20190814    28.13     0.001
# 914  20190905    29.49     0.005
# 915  20191003    29.63     0.004
#
# [1353 rows x 3 columns]

# %%
dfni = pd.read_hdf('/home/poyraden/Analysis/Homogenization_Analysis/Files/Nilu/Sodankyl/Raw/All_metadata.hdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-aa38405c784f> in <module>
# ----> 1 dfni = pd.read_hdf('/home/poyraden/Analysis/Homogenization_Analysis/Files/Nilu/Sodankyl/Raw/All_metadata.hdf')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     393
#     394         if not exists:
# --> 395             raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     396
#     397         store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#
# FileNotFoundError: File /home/poyraden/Analysis/Homogenization_Analysis/Files/Nilu/Sodankyl/Raw/All_metadata.hdf does not exist

# %%
dfni = dfni.sort_values(['Date'])

# %%
dfni
# Out:
#     Number of pressure levels  \
# 0                        3421
# 1                        3021
# 2                        3195
# 3                        3491
# 4                        2917
# ..                        ...
# 940                       NaN
# 941                       NaN
# 942                       NaN
# 943                       NaN
# 944                       NaN
#
#     Launch time (Decimal UT hours from 0 hours on day given by DATE)  \
# 0                                               11.517
# 1                                                4.800
# 2                                                4.317
# 3                                               11.517
# 4                                                5.150
# ..                                                 ...
# 940                                               9.86
# 941                                               9.89
# 942                                               9.69
# ...

# %%
print(list(dfa))
# Out:
# ['BkgUsed', 'LaunchTime', 'Longitude', 'Latitude', 'SolutionVolume', 'SolutionConcentration', 'PF', 'iB0', 'iB2', 'DurationSurfaceOzoneExposure', 'SurfaceOzone', 'Pground', 'SondeTotalO3', 'TotalO3_Col2A', 'TotalO3_Col2B', 'CorrectionFactor', 'TLab', 'ULab', 'GroundEquipment', 'PumpTable', 'BackgroundCorrection', 'SerialECC', 'SensorType', 'InterfaceSerial', 'RadiosondeModel', 'RadiosondeSerial', 'Date', 'PumpTempLoc']

# %%
dfa[['Date','SensorType', 'SerialECC','SolutionConcentration']]
# Out:
#          Date SensorType SerialECC SolutionConcentration
# 916  19911120        SPC    5a8363                   NaN
# 917  19911127        SPC    5a2963                   NaN
# 918  19911202        SPC    5A2958                   NaN
# 919  19911203        SPC    5a2959                   NaN
# 920  19911204        SPC    5a2547                   NaN
# ..        ...        ...       ...                   ...
# 911  20190709      DMT-Z   Z32022u                   5.0
# 912  20190725      DMT-Z   Z32012u                   5.0
# 913  20190814      DMT-Z   Z32024u                   5.0
# 914  20190905      DMT-Z   Z32052u                   5.0
# 915  20191003      DMT-Z   Z32048u                   5.0
#
# [1353 rows x 4 columns]

# %%
dfa.SolutionVolume.astype(float).min()
# Out:
# 2.5

# %%
dfa[(dfa.SolutionConcentration.astype(float) == 5) & (dfa.SensorType =='SPC')]['Date']
# Out:
# Series([], Name: Date, dtype: object)

# %%
dfa.Date.max(), dfa.Date.min()
# Out:
# ('20191003', '19911120')

# %%
dfa = dfa[dfa.Date > '20040101']

# %%
dfa[['Date','SolutionConcentration', 'SensorType']]
# Out:
#          Date SolutionConcentration SensorType
# 262  20040107                  10.0        SPC
# 263  20040114                  10.0      DMT-Z
# 264  20040128                  10.0      DMT-Z
# 265  20040204                  10.0      DMT-Z
# 266  20040303                  10.0        SPC
# ..        ...                   ...        ...
# 911  20190709                   5.0      DMT-Z
# 912  20190725                   5.0      DMT-Z
# 913  20190814                   5.0      DMT-Z
# 914  20190905                   5.0      DMT-Z
# 915  20191003                   5.0      DMT-Z
#
# [654 rows x 3 columns]

# %%
dfm  = pd.read_csv('/home/poyraden/Analysis/Homogenization_public/Files/sodankyla/DQA/20040114_o3smetadata.csv')

# %%
df = pd.read_hdf('/home/poyraden/Analysis/Homogenization_public/Files/sodankyla/DQA/20040114_all_hom_nors80.hdf')

# %%
print(list(df))
# Out:
# ['Pair', 'Time', 'Height', 'TboxK', 'TboxC', 'WindDirection', 'WindSpeed', 'O3', 'T', 'U', 'SensorType', 'SolutionVolume', 'Cef', 'ibg', 'iB2', 'I', 'Date', 'Tpump', 'Phip', 'stoich', 'unc_stoich', 'eta_c', 'unc_eta', 'unc_eta_c', 'Tpump_cor', 'Cpf', 'unc_Cpf', 'Phip_cor', 'unc_Phip_cor', 'O3c', 'O3_nc', 'O3c_eta', 'O3c_bkg', 'O3c_etabkg', 'O3c_phip', 'O3c_etabkgphip', 'O3c_tpump', 'dIall', 'dEta', 'dPhi_cor', 'dTpump_cor', 'dO3']

# %%
df[['eta_c','stoich', 'O3c', 'O3_nc', 'O3c_eta']]
# Out:
#          eta_c    stoich       O3c     O3_nc   O3c_eta
# 1     1.041667  0.960000  1.823065  1.859914  1.785517
# 2     1.041667  0.960000  1.823065  1.859914  1.785517
# 3     1.041667  0.960000  1.813266  1.849914  1.775918
# 4     1.041667  0.960000  1.813267  1.849914  1.775918
# 5     1.041667  0.960000  1.793667  1.829915  1.756718
# ...        ...       ...       ...       ...       ...
# 2688  1.061340  0.942205  6.032485  5.855872  5.517430
# 2689  1.061529  0.942038  6.069582  5.891476  5.549992
# 2690  1.061719  0.941869  6.106648  5.927056  5.582509
# 2691  1.061911  0.941698  6.163034  5.981392  5.632667
# 2692  1.062105  0.941526       NaN       NaN       NaN
#
# [2692 rows x 5 columns]

# %%
dfm['eta_c']
# Out:
# 0    1.041667
# Name: eta_c, dtype: float64

# %%
dfa[(dfa.SolutionConcentration.astype('float') == 5) & (dfa.SensorType == 'SPC') ][['Date', 'SolutionConcentration', 'SensorType']]
# Out:
# Empty DataFrame
# Columns: [Date, SolutionConcentration, SensorType]
# Index: []

# %%
dfas[(dfas.SolutionConcentration.astype(float) == 10) & (dfas.SensorType == 'DMT-Z') & (dfas.Date > '20040101')][['Date', 'SolutionConcentration','SensorType']]
# Out:
#          Date SolutionConcentration SensorType
# 263  20040114                  10.0      DMT-Z
# 264  20040128                  10.0      DMT-Z
# 265  20040204                  10.0      DMT-Z
# 267  20040310                  10.0      DMT-Z
# 269  20040324                  10.0      DMT-Z
# 272  20040414                  10.0      DMT-Z
# 276  20040519                  10.0      DMT-Z
# 279  20040609                  10.0      DMT-Z
# 280  20040616                  10.0      DMT-Z
# 282  20040630                  10.0      DMT-Z
# 286  20040804                  10.0      DMT-Z

# %%
dfas[(dfas.SolutionConcentration == '10.0') & (dfas.SensorType == 'DMT-Z') & (dfas.Date > '20040101')][['Date', 'SolutionConcentration','SensorType']]
# Out:
#          Date SolutionConcentration SensorType
# 263  20040114                  10.0      DMT-Z
# 264  20040128                  10.0      DMT-Z
# 265  20040204                  10.0      DMT-Z
# 267  20040310                  10.0      DMT-Z
# 269  20040324                  10.0      DMT-Z
# 272  20040414                  10.0      DMT-Z
# 276  20040519                  10.0      DMT-Z
# 279  20040609                  10.0      DMT-Z
# 280  20040616                  10.0      DMT-Z
# 282  20040630                  10.0      DMT-Z
# 286  20040804                  10.0      DMT-Z

# %%
dfas[(dfas.SolutionConcentration == 5.0)  ][['Date', 'SolutionConcentration']]
# Out:
# Empty DataFrame
# Columns: [Date, SolutionConcentration]
# Index: []

# %%
dfas[(dfas.SolutionConcentration == 5.0) & (dfas.SensorType == 'DMT-Z') ][['Date', 'SolutionConcentration']]
# Out:
# Empty DataFrame
# Columns: [Date, SolutionConcentration]
# Index: []

# %%
dfas[(dfas.Date == '20050222') ][['Date', 'iB2','TLab']]
# Out:
#          Date     iB2 TLab
# 291  20050222  9999.0  NaN

# %%
dfa[(dfa.SensorType != 'SPC') ][['SensorType','SolutionConcentration' ]]
# Out:
#      SensorType  SolutionConcentration
# 14        DMT-Z                   10.0
# 15        DMT-Z                   10.0
# 16        DMT-Z                   10.0
# 17        DMT-Z                   10.0
# 18        DMT-Z                   10.0
# ...         ...                    ...
# 1252      DMT-Z                   10.0
# 1253      DMT-Z                   10.0
# 1260      DMT-Z                   10.0
# 1269      DMT-Z                   10.0
# 1293      DMT-Z                   10.0
#
# [765 rows x 2 columns]

# %%
dfa[(dfa.SolutionConcentration != 5) & (dfa.SolutionConcentration != 10)   ][['Date', 'SensorType','SolutionConcentration' ]]
# Out:
#           Date SensorType  SolutionConcentration
# 291   20050222        SPC                    NaN
# 292   20050301        SPC                    NaN
# 293   20050322      DMT-Z                    NaN
# 294   20050412      DMT-Z                    NaN
# 295   20051109        SPC                    3.0
# ...        ...        ...                    ...
# 1125  19961231        SPC                    NaN
# 1126  19970101        SPC                    NaN
# 1127  19970103        SPC                    NaN
# 1128  19970104        SPC                    NaN
# 1129  19970105        SPC                    NaN
#
# [254 rows x 3 columns]

# %%
dfa[(dfa.SolutionConcentration == 3) & (dfa.SolutionConcentration != 10)   ][['Date', 'SensorType','SolutionConcentration' ]]
# Out:
#          Date SensorType  SolutionConcentration
# 295  20051109        SPC                    3.0
# 296  20051124        SPC                    3.0
# 315  20060427      DMT-Z                    3.0
# 318  20060517      DMT-Z                    3.0

# %%
dfa[(dfa.SolutionConcentration == 10) & (dfa.SensorType == 'DMT-Z')   ][['Date', 'SensorType','SolutionConcentration' ]]
# Out:
#           Date SensorType  SolutionConcentration
# 14    20000217      DMT-Z                   10.0
# 15    20000218      DMT-Z                   10.0
# 16    20000218      DMT-Z                   10.0
# 17    20000223      DMT-Z                   10.0
# 18    20000224      DMT-Z                   10.0
# ...        ...        ...                    ...
# 1252  19980506      DMT-Z                   10.0
# 1253  19980514      DMT-Z                   10.0
# 1260  19980701      DMT-Z                   10.0
# 1269  19980909      DMT-Z                   10.0
# 1293  19990105      DMT-Z                   10.0
#
# [115 rows x 3 columns]

# %%
print(sorted(dfa[(dfa.SolutionConcentration != 5) & (dfa.SolutionConcentration != 10)]['Date' ].tolist()))
# Out:
# [19911120, 19911127, 19911202, 19911203, 19911204, 19911209, 19911211, 19911212, 19911213, 19911216, 19911218, 19911225, 19911229, 19920108, 19920113, 19920114, 19920115, 19920120, 19920121, 19920122, 19920123, 19920127, 19920131, 19920202, 19920204, 19920205, 19920206, 19920208, 19920210, 19920212, 19920214, 19920221, 19920224, 19920226, 19920228, 19920302, 19920304, 19920309, 19920311, 19920313, 19920316, 19920318, 19920320, 19920323, 19940105, 19940113, 19940119, 19940121, 19940124, 19940126, 19940130, 19940202, 19940209, 19940211, 19940214, 19940216, 19940302, 19940304, 19940309, 19940311, 19940314, 19940316, 19940317, 19940318, 19940319, 19940321, 19940325, 19940328, 19940406, 19940413, 19940420, 19940511, 19940518, 19940601, 19940608, 19940615, 19940622, 19940629, 19940706, 19940713, 19940720, 19940727, 19940803, 19940810, 19940817, 19940824, 19940831, 19940906, 19940915, 19940922, 19940928, 19941005, 19941012, 19941019, 19941102, 19941109, 19941116, 19941130, 19941207, 1994122
# ...

# %%
dfa[['Date', 'iB0', 'iB2']]
# Out:
#           Date    iB0    iB2
# 0     20000105  0.027  0.019
# 1     20000107  0.025  0.020
# 2     20000112  0.034  0.033
# 3     20000117  0.038  0.035
# 4     20000120  0.050  0.000
# ...        ...    ...    ...
# 1348  19991124  0.070  0.048
# 1349  19991201  0.027  0.024
# 1350  19991208  0.040  0.027
# 1351  19991215  0.004  0.017
# 1352  19991229  0.051  0.030
#
# [1353 rows x 3 columns]

# %%
dfas = dfa.sort_values(['Date'])

# %%
dfas[dfas.PF < 999][['Date','PF']]
# Out:
#           Date     PF
# 1130  19970107  26.25
# 1131  19970108  27.26
# 1132  19970109  27.40
# 1133  19970111  27.50
# 1134  19970114  27.60
# ...        ...    ...
# 911   20190709  28.58
# 912   20190725  28.15
# 913   20190814  28.13
# 914   20190905  29.49
# 915   20191003  29.63
#
# [1135 rows x 2 columns]

# %%
dfas[dfas.iB0 < 1][['Date', 'iB0', 'iB2','PF']]
# Out:
#           Date    iB0    iB2     PF
# 1130  19970107  0.250  0.106  26.25
# 1131  19970108  0.250  0.140  27.26
# 1132  19970109  0.150  0.085  27.40
# 1133  19970111  0.200  0.136  27.50
# 1134  19970114  0.083  0.083  27.60
# ...        ...    ...    ...    ...
# 911   20190709  0.009  0.002  28.58
# 912   20190725  0.004  0.007  28.15
# 913   20190814  0.005  0.001  28.13
# 914   20190905  0.006  0.005  29.49
# 915   20191003  0.005  0.004  29.63
#
# [1133 rows x 4 columns]

# %%
dfas[dfas.iB2 < 1][['Date', 'iB0', 'iB2','ULab']]
# Out:
#           Date    iB0    iB2  ULab
# 1130  19970107  0.250  0.106   NaN
# 1131  19970108  0.250  0.140   NaN
# 1132  19970109  0.150  0.085   NaN
# 1133  19970111  0.200  0.136   NaN
# 1134  19970114  0.083  0.083   NaN
# ...        ...    ...    ...   ...
# 911   20190709  0.009  0.002  31.0
# 912   20190725  0.004  0.007  45.0
# 913   20190814  0.005  0.001  39.0
# 914   20190905  0.006  0.005  33.0
# 915   20191003  0.005  0.004  23.0
#
# [1135 rows x 4 columns]

# %%
dfas[dfas.Date > 19981230][['Date', 'iB0', 'iB2','ULab']]
# Out:
#           Date    iB0    iB2  ULab
# 1292  19990101  0.043  0.048  30.0
# 1293  19990105  0.054  0.050  33.0
# 1294  19990106  0.045  0.043  32.0
# 1295  19990108  0.041  0.032  26.0
# 1296  19990112  0.095  0.037  28.0
# ...        ...    ...    ...   ...
# 911   20190709  0.009  0.002  31.0
# 912   20190725  0.004  0.007  45.0
# 913   20190814  0.005  0.001  39.0
# 914   20190905  0.006  0.005  33.0
# 915   20191003  0.005  0.004  23.0
#
# [977 rows x 4 columns]

# %%
dfu = pd.read_csv('/home/poyraden/Analysis/Homogenization_public/Files/uccle/Binned/UccleInterpolated_raw_nors80.csv')

# %%
dfu
# Out:
#        Unnamed: 0      Date    PreLevel  PO3_UcMean  PO3_UcMedian  \
# 0               0  19961023  1000.00000         NaN           NaN
# 1               1  19961023   825.40400         NaN           NaN
# 2               2  19961023   681.29200         NaN           NaN
# 3               3  19961023   562.34100         NaN           NaN
# 4               4  19961023   464.15900         NaN           NaN
# ...           ...       ...         ...         ...           ...
# 36535       36535  20201218    12.11530         NaN           NaN
# 36536       36536  20201218    10.00000         NaN           NaN
# 36537       36537  20201218     8.25404         NaN           NaN
# 36538       36538  20201218     6.81292         NaN           NaN
# 36539       36539  20201218     5.62341         NaN           NaN
#
#        PO3_UcIntLin
# 0          5.150717
# 1          6.002673
# 2          6.192325
# 3          6.032188
# 4          5.953161
# ...             ...
# 36535      5.543415
# ...

# %%
y = [i for i in range(1996, 2021)]

# %%
print(y)
# Out:
# [1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
len(y)
# Out:
# 25
